# %% [markdown]
# ## Import

# %%
import os, sys, inspect, time

import numpy as np
import torch 
import matplotlib.pyplot as plt
torch.multiprocessing.set_sharing_strategy('file_system')

import discrepancy, visualization
from algorithms import ABC_algorithms, SMCABC, SMC2ABC, SNLABC, SNL2ABC
from problems import problem_OP

import utils_os, utils_math

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Problem Definition

# %%
DIR = 'results/OP'                                             
RERUN = not utils_os.is_file_exist(DIR, 'true_samples.npy') 

## Define the problem
problem = problem_OP.OP_Problem(N=2000, n=50)
true_theta = problem.get_true_theta()

## Get x_o ~ p(x|theta)
if RERUN:
    # observed data x_o
    problem.data_obs = problem.simulator(true_theta)
    problem.y_obs = problem.statistics(data=problem.data_obs, theta=true_theta)
    utils_os.save_object(DIR, 'data_obs', problem.data_obs)
    utils_os.save_object(DIR, 'y_obs', problem.y_obs)
    
    # true samples theta ~ pi(theta|x_o)
    true_samples = problem.sample_from_true_posterior()
    utils_os.save_object(DIR, 'true_samples', true_samples)
else:
    # load previously simulated true samples & x_o
    true_samples = utils_os.load_object(DIR, 'true_samples.npy')
    problem.data_obs  = utils_os.load_object(DIR, 'data_obs.npy')
    problem.y_obs  = utils_os.load_object(DIR, 'y_obs.npy')
    
## Visualize
problem.visualize()   
visualization.plot_likelihood(samples=true_samples, log_likelihood_function=problem.log_likelihood, dimensions=(0,1))
plt.savefig('OP_true_posterior.png')
# Out:
# mean-parma1 =  0.3720654037899112      mean-param2 =  0.21902819231692378

# %% [markdown]
# ## Inference

# %% [markdown]
# ### SMC-ABC

# %%
## Sequential Monte Carlo ABC

hyperparams = ABC_algorithms.Hyperparams()
hyperparams.save_dir = DIR
hyperparams.device = 'cuda:1'
hyperparams.num_sim = 4000                        # number of simulations
hyperparams.num_samples = 200                     # number of samples to represent posterior
hyperparams.L = 2                                 # number of rounds in sequential learning

smc_abc = SMCABC.SMC_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
smc_abc.run()

JSD_smc_array = []
for l in range(hyperparams.L):
    print('round =', l)
    smc_abc.posterior = smc_abc.posterior_array[l]
    visualization.plot_likelihood(samples=true_samples, log_likelihood_function=smc_abc.log_likelihood, dimensions=(0,1))
    JSD = discrepancy.JSD(problem.log_likelihood, smc_abc.log_likelihood, true_samples, true_samples, N_grid=30)
    JSD_smc_array.append(JSD)
    print('JSD smc = ', JSD)
utils_os.save_object(DIR, 'JSD_SMC', JSD_smc_array)
# Out:
# iteration  0
# # of cpus =  4
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [sampling] finished sampling  100
# [sampling] finished sampling  200
# [sampling] finished sampling  300
# [sampling] finished sampling  400
# > learning fake posterior
# > learning true posterior
#
#
# iteration  1
# # of cpus =  4
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [sampling] finished sampling  100
# [sampling] finished sampling  200
# [sampling] finished sampling  300
# [sampling] finished sampling  400
# > learning fake posterior
# fitting Gaussian copula progress= 0.0 loss= 418.7857360839844
# fitting Gaussian copula progress= 0.1 loss= 24.871540069580078
# fitting Gaussian copula progress= 0.2 loss= -113.09133911132812
# fitting Gaussian copula progress= 0.3 loss= -171.73681640625
# fitting Gaussian copula progress= 0.4 loss= -180.22866821289062
# fitting Gaussian copula progress= 0.5 loss= -180.82887268066406
# fitting Gaussian copula progress= 0.6 loss= -181.07545471191406
# fitting Gaussian copula progress= 0.7 loss= -181.21810913085938
# fitting Gaussian copula progress= 0.8 loss= -181.30303955078125
# fitting Gaussian copula progress= 0.0 loss= 253.5533905029297
# fitting Gaussian copula progress= 0.1 loss= 156.10205078125
# fitting Gaussian copula progress= 0.2 loss= 144.6427001953125
# fitting Gaussian copula progress= 0.3 loss= 143.93756103515625
# fitting Gaussian copula progress= 0.4 loss= 143.5714874267578
# > learning true posterior
# fitting Gaussian copula progress= 0.0 loss= 2001.1795654296875
# fitting Gaussian copula progress= 0.1 loss= 238.75918579101562
# fitting Gaussian copula progress= 0.2 loss= -1033.632080078125
# fitting Gaussian copula progress= 0.3 loss= -1615.525634765625
# fitting Gaussian copula progress= 0.0 loss= 3359.45361328125
# fitting Gaussian copula progress= 0.1 loss= 2035.4073486328125
# fitting Gaussian copula progress= 0.2 loss= 1707.76220703125
# fitting Gaussian copula progress= 0.3 loss= 1623.3447265625
# fitting Gaussian copula progress= 0.4 loss= 1606.37255859375
# fitting Gaussian copula progress= 0.5 loss= 1602.4188232421875
# fitting Gaussian copula progress= 0.6 loss= 1599.70458984375
# fitting Gaussian copula progress= 0.7 loss= 1595.703125
# fitting Gaussian copula progress= 0.8 loss= 1578.72998046875
#
#
# round = 0
# mean-parma1 =  0.3720654037899112      mean-param2 =  0.21902819231692378
# JSD smc =  [0.1728342]
# round = 1
# mean-parma1 =  0.3720654037899112      mean-param2 =  0.21902819231692378
# JSD smc =  [0.01941569]

# %%
## Sequential Monte Carlo ABC +

hyperparams = ABC_algorithms.Hyperparams()
hyperparams.save_dir = DIR
hyperparams.device =   "cuda:0"
hyperparams.num_sim = 4000                       # number of simulations
hyperparams.num_samples = 200                    # number of samples to represent posterior
hyperparams.L = 2                                # number of learning rounds
hyperparams.hidden_ratio = 0.10                  # dimensionality of S(x)
hyperparams.type = 'plain'                       # the network architecture of S(x)
hyperparams.estimator = 'JSD'                    # MI estimator; JSD (accurate) or DC (fast)

smc2_abc = SMC2ABC.SMC2_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
smc2_abc.run()

JSD_smc2_array = []
for l in range(len(smc2_abc.posterior_array)):
    print('l=', l)
    smc2_abc.l = l
    smc2_abc.posterior = smc2_abc.posterior_array[l]
    visualization.plot_likelihood(samples=true_samples, log_likelihood_function=smc2_abc.log_likelihood, dimensions=(0,1))
    JSD = discrepancy.JSD(problem.log_likelihood, smc2_abc.log_likelihood, true_samples, true_samples, N_grid=30)
    JSD_smc2_array.append(JSD)
    print('JSD smc2 = ', JSD)
utils_os.save_object(DIR, 'JSD_SMC2', JSD_smc2_array)
# Out:
# iteration  0
# # of cpus =  4
# [ABC] sub-process start!
# [ABC] sub-process start![ABC] sub-process start!
#
# [ABC] sub-process start!
# [sampling] finished sampling  100
# [sampling] finished sampling  200
# [sampling] finished sampling  300
# [sampling] finished sampling  400
#
#  > fitting encoder
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_30034/3977327481.py in <module>
#      12
#      13 smc2_abc = SMC2ABC.SMC2_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
# ---> 14 smc2_abc.run()
#      15
#      16 JSD_smc2_array = []
#
# /mnt/work/git/python/others/neural-approx-ss-lfi/algorithms/SMC2ABC.py in run(self)
#     229             self.all_stats.append(self.stats)
#     230             self.all_samples.append(self.samples)
# --> 231             self.fit_vae()
#     232             self.sort_samples()
#     233             self.learn_fake_posterior()
#
# /mnt/work/git/python/others/neural-approx-ss-lfi/algorithms/SMC2ABC.py in fit_vae(self)
#      57     def fit_vae(self):
#      58         print('\n > fitting encoder')
# ---> 59         all_stats = torch.tensor(np.vstack(self.all_stats)).float().to(self.device)
#      60         all_samples = torch.tensor(np.vstack(self.all_samples)).float().to(self.device)
#      61         [n, dim] = all_stats.size()
#
# ~/.local/lib/python3.8/site-packages/torch/cuda/__init__.py in _lazy_init()
#     206                 "multiprocessing, you must use the 'spawn' start method")
#     207         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 208             raise AssertionError("Torch not compiled with CUDA enabled")
#     209         if _cudart is None:
#     210             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %% [markdown]
# ### SNL

# %%
## Sequential Neural Likelihood
hyperparams = ABC_algorithms.Hyperparams()
hyperparams.save_dir = DIR
hyperparams.device = 'cuda:1'
hyperparams.num_sim = 4000
hyperparams.L = 2

print('\n SNL ABC')
snl_abc = SNLABC.SNL_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
snl_abc.run()

JSD_array = []
for l in range(len(snl_abc.nde_array)):
    print('l=', l)
    snl_abc.nde_net = snl_abc.nde_array[l]
    visualization.plot_likelihood(samples=true_samples, log_likelihood_function=snl_abc.log_likelihood, dimensions=(0,1))
    JSD = discrepancy.JSD(problem.log_likelihood, snl_abc.log_likelihood, true_samples, true_samples, N_grid=30)
    JSD_array.append(JSD)
    print('JSD snl = ', JSD)
utils_os.save_object(DIR, 'JSD_SNL', JSD_array)
# Out:
#  SNL ABC
# iteration  0
# # of cpus =  4
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [ABC] sub-process start!
# [sampling] finished sampling  100
# [sampling] finished sampling  200
# [sampling] finished sampling  300
# [sampling] finished sampling  400
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_30034/1701056366.py in <module>
#       8 print('\n SNL ABC')
#       9 snl_abc = SNLABC.SNL_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
# ---> 10 snl_abc.run()
#      11
#      12 JSD_array = []
#
# /mnt/work/git/python/others/neural-approx-ss-lfi/algorithms/SNLABC.py in run(self)
#     117             self.all_stats.append(self.stats)
#     118             self.all_samples.append(self.samples)
# --> 119             self.fit_nde()
#     120             self.prior = self.sample_from_nde
#     121             print('\n')
#
# /mnt/work/git/python/others/neural-approx-ss-lfi/algorithms/SNLABC.py in fit_nde(self)
#      48
#      49     def fit_nde(self):
# ---> 50         all_stats = torch.tensor(np.vstack(self.all_stats)).float().to(self.device)
#      51         all_samples = torch.tensor(np.vstack(self.all_samples)).float().to(self.device)
#      52         [n, dim] = all_stats.size()
#
# ~/.local/lib/python3.8/site-packages/torch/cuda/__init__.py in _lazy_init()
#     206                 "multiprocessing, you must use the 'spawn' start method")
#     207         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 208             raise AssertionError("Torch not compiled with CUDA enabled")
#     209         if _cudart is None:
#     210             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
### Sequential Neural Likelihood + 
hyperparams = ABC_algorithms.Hyperparams()
hyperparams.save_dir = DIR
hyperparams.device = 'cuda:1'
hyperparams.num_sim = 4000                       # number of simulations
hyperparams.L = 2                                # number of learning rounds
hyperparams.hidden_ratio = 0.10                  # dimensionality of S(x)
hyperparams.type = 'plain'                       # the network architecture of S(x)
hyperparams.estimator = 'JSD'                    # MI estimator; JSD (accurate) or DC (fast)
hyperparams.nde = 'MAF'                          # nde; MAF (D>1) or MDN (D=1)

snl2_abc = SNL2ABC.SNL2_ABC(problem, discrepancy=discrepancy.eculidean_dist, hyperparams=hyperparams)
snl2_abc.run()

JSD_array = []
for l in range(len(snl2_abc.nde_array)):
    print('l=', l)
    snl2_abc.set(l=l)
    visualization.plot_likelihood(samples=true_samples, log_likelihood_function=snl2_abc.log_likelihood, dimensions=(0,1))
    JSD = discrepancy.JSD(problem.log_likelihood, snl2_abc.log_likelihood, true_samples, true_samples, N_grid=30)
    JSD_array.append(JSD)
    print('JSD snl+ = ', JSD)
utils_os.save_object(DIR, 'JSD_SNL2', JSD_array)
